# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
from io import StringIO
pd.set_option('display.max_rows', 500)

# %%
league = "Premier-League"
season = "2023-2024"

LEAGUE_URLS = {
    'Premier-League': f'https://fbref.com/en/comps/9/{season}/schedule/{season}-Premier-League-Scores-and-Fixtures',
    'La-Liga': f'https://fbref.com/en/comps/12/{season}/schedule/{season}-La-Liga-Scores-and-Fixtures'
}

url = LEAGUE_URLS.get(league)
if not url:
    print(f"Unknown league: {league}.")

response = requests.get(url)
print(str(response.status_code))

if response.status_code != 200:
    print("Error getting response from http request.")
    
url_league_num = url.split('/')[5]
table_id = f'sched_{season}_{url_league_num}_1'
print(table_id)

soup = BeautifulSoup(response.text, 'html.parser')
schedule_table = soup.find('table', {'id': table_id})

# %%
df = pd.read_html(StringIO(str(schedule_table)))[0]
df = df.dropna(how='all')
# Out:
#     Wk  Day        Date   Time           Home   xG Score  xG.1  \
# 0  1.0  Fri  2023-08-11  20:00        Burnley  0.3   0–3   1.9
# 1  1.0  Sat  2023-08-12  12:30        Arsenal  0.8   2–1   1.2
# 2  1.0  Sat  2023-08-12  15:00        Everton  2.7   0–1   1.5
# 3  1.0  Sat  2023-08-12  15:00  Sheffield Utd  0.5   0–1   1.9
# 4  1.0  Sat  2023-08-12  15:00       Brighton  4.0   4–1   1.5
#
#               Away  Attendance                                   Venue  \
# 0  Manchester City     21572.0                               Turf Moor
# 1  Nott'ham Forest     59984.0                        Emirates Stadium
# 2           Fulham     39940.0                           Goodison Park
# 3   Crystal Palace     31194.0                            Bramall Lane
# 4       Luton Town     31872.0  The American Express Community Stadium
#
#           Referee  Match Report  Notes
# 0    Craig Pawson  Match Report    NaN
# 1  Michael Oliver  Match Report    NaN
# 2  Stuart Attwell  Match Report    NaN
# 3     John Brooks  Match Report    NaN
# 4     David Coote  Match Report    NaN

# %%
df[['home_score', 'away_score']] = df['Score'].str.split(r'\D+', expand=True)
df = df.rename({'Home': 'home', 
                'Away': 'away', 
                'Date': 'match_date'}, axis="columns")
df['league'] = league
df['season'] = season
COLS_KEEP = ['match_date', 'league', 'season', 'home', 'away', 'home_score', 'away_score']
df.head()
# Out:
#     Wk  Day  match_date   Time           home   xG Score  xG.1  \
# 0  1.0  Fri  2023-08-11  20:00        Burnley  0.3   0–3   1.9
# 1  1.0  Sat  2023-08-12  12:30        Arsenal  0.8   2–1   1.2
# 2  1.0  Sat  2023-08-12  15:00        Everton  2.7   0–1   1.5
# 3  1.0  Sat  2023-08-12  15:00  Sheffield Utd  0.5   0–1   1.9
# 4  1.0  Sat  2023-08-12  15:00       Brighton  4.0   4–1   1.5
#
#               away  Attendance                                   Venue  \
# 0  Manchester City     21572.0                               Turf Moor
# 1  Nott'ham Forest     59984.0                        Emirates Stadium
# 2           Fulham     39940.0                           Goodison Park
# 3   Crystal Palace     31194.0                            Bramall Lane
# 4       Luton Town     31872.0  The American Express Community Stadium
#
#           Referee  Match Report  Notes home_score away_score          league  \
# 0    Craig Pawson  Match Report    NaN          0          3  Premier-League
# 1  Michael Oliver  Match Report    NaN          2          1  Premier-League
# 2  Stuart Attwell  Match Report    NaN          0          1  Premier-League
# 3     John Brooks  Match Report    NaN          0          1  Premier-League
# 4     David Coote  Match Report    NaN          4          1  Premier-League
#
#       season
# 0  2023-2024
# 1  2023-2024
# 2  2023-2024
# 3  2023-2024
# 4  2023-2024

# %%
df = df[COLS_KEEP]
df.head()
# Out:
#    match_date          league     season           home             away  \
# 0  2023-08-11  Premier-League  2023-2024        Burnley  Manchester City
# 1  2023-08-12  Premier-League  2023-2024        Arsenal  Nott'ham Forest
# 2  2023-08-12  Premier-League  2023-2024        Everton           Fulham
# 3  2023-08-12  Premier-League  2023-2024  Sheffield Utd   Crystal Palace
# 4  2023-08-12  Premier-League  2023-2024       Brighton       Luton Town
#
#   home_score away_score
# 0          0          3
# 1          2          1
# 2          0          1
# 3          0          1
# 4          4          1

# %%
df['match_date'] = pd.to_datetime(df['match_date'], errors='coerce').dt.date
df['home_score'] = pd.to_numeric(df['home_score'], errors='coerce').fillna(0).astype(int)
df['away_score'] = pd.to_numeric(df['away_score'], errors='coerce').fillna(0).astype(int)

# %%
df.head()
# Out:
#    match_date          league     season           home             away  \
# 0  2023-08-11  Premier-League  2023-2024        Burnley  Manchester City
# 1  2023-08-12  Premier-League  2023-2024        Arsenal  Nott'ham Forest
# 2  2023-08-12  Premier-League  2023-2024        Everton           Fulham
# 3  2023-08-12  Premier-League  2023-2024  Sheffield Utd   Crystal Palace
# 4  2023-08-12  Premier-League  2023-2024       Brighton       Luton Town
#
#    home_score  away_score
# 0           0           3
# 1           2           1
# 2           0           1
# 3           0           1
# 4           4           1
